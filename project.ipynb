# %%
import pandas as pd 
import numpy as np 
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv")

# %%
data
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0      1001    55601   6787               12.206615    7637
# 1      1003   218022  24757               11.355276   26913
# 2      1005    24881   2732               10.980266    2960
# 3      1007    22400   2456               10.964286    2596
# 4      1009    57840   7095               12.266598    7570
# ...     ...      ...    ...                     ...     ...
# 3135  56037    43051   6104               14.178532    6326
# 3136  56039    23081   2384               10.328842    2185
# 3137  56041    20299   3121               15.375142    3205
# 3138  56043     7885    858               10.881420    1113
# 3139  56045     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Columns: 108 entries, fips to Urban_rural_code
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB

# %%
data.isna().sum()
# Out:
# fips                      0
# TOT_POP                   0
# 0-9                       0
# 0-9 y/o % of total pop    0
# 19-Oct                    0
#                          ..
# CKD_prevalence            0
# CKD_Lower 95% CI          0
# CKD_Upper 95% CI          0
# CKD_number                0
# Urban_rural_code          0
# Length: 108, dtype: int64

# %%
data.describe().round(2)
# Out:
#            fips      TOT_POP        0-9  0-9 y/o % of total pop      19-Oct  \
# count   3140.00      3140.00     3140.0                 3140.00     3140.00
# mean   30401.64    104189.41    12740.3                   11.87    13367.98
# std    15150.56    333583.40    41807.3                    2.12    42284.39
# min     1001.00        88.00        0.0                    0.00        0.00
# 25%    18180.50     10963.25     1280.5                   10.59     1374.50
# 50%    29178.00     25800.50     3057.0                   11.80     3274.00
# 75%    45081.50     67913.00     8097.0                   12.95     8822.25
# max    56045.00  10105518.00  1208253.0                   25.46  1239139.00
#
#        10-19 y/o % of total pop       20-29  20-29 y/o % of total pop  \
# count                   3140.00     3140.00                   3140.00
# mean                      12.69    14469.33                     12.28
# std                        1.82    49577.73                      3.13
# ...

# %%
data.columns
# Out:
# Index(['fips', 'TOT_POP', '0-9', '0-9 y/o % of total pop', '19-Oct',
#        '10-19 y/o % of total pop', '20-29', '20-29 y/o % of total pop',
#        '30-39', '30-39 y/o % of total pop',
#        ...
#        'COPD_number', 'diabetes_prevalence', 'diabetes_Lower 95% CI',
#        'diabetes_Upper 95% CI', 'diabetes_number', 'CKD_prevalence',
#        'CKD_Lower 95% CI', 'CKD_Upper 95% CI', 'CKD_number',
#        'Urban_rural_code'],
#       dtype='object', length=108)

# %%
data = pd.get_dummies(data)

# %%
X_train = data.drop(["Heart disease_number"], axis = 1)
y_train = data["Heart disease_number"]
X_test = data.drop(["Heart disease_number"], axis = 1)
y_test = data["Heart disease_number"]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Intercept (a): {model.intercept_}")
print(f"Coefficients (b): {model.coef_}")
# Out:
# Intercept (a): -7038.528278552568
# Coefficients (b): [ 5.86900802e-03  2.18465749e-02  6.96063104e-02 ...  5.21970945e+02
#  -1.78543318e+02  9.62122926e+01]

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([ 3345.00000094, 13554.73130169,  2261.71304061, ...,
#         1033.99999894,   499.99999938,   470.99999933], shape=(3140,))

# %%
from sklearn.metrics import mean_squared_error, r2_score

print(f"Mean squared error: {mean_squared_error(y_test, y_pred)}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred)}")
# Out:
# Mean squared error: 17530.13654291547
# Coefficient of determination: 0.9999280842898646

# %%
from sklearn.linear_model import Lasso

 #Load of train and test data
 #These data must have been standardized and correctly processed in a complete EDA


lasso_model = Lasso(alpha = 0.1, max_iter = 300)

lasso_model.fit(X_train, y_train)

y_pred = lasso_model.predict(X_test)

y_pred
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.910e+08, tolerance: 7.654e+07
#   model = cd_fast.enet_coordinate_descent(
# array([ 3290.97804531, 14005.55472728,  2293.55460798, ...,
#          907.30611693,   392.99179616,   499.36333313], shape=(3140,))

# %%
from sklearn.linear_model import Ridge  

# Load of train and test data  
# These data must have been standardized and correctly processed in a complete EDA  

# Assuming X_train and y_train are already defined  
ridge_model = Ridge(alpha=0.1, max_iter=300)  

# Fit the model on the training data  
ridge_model.fit(X_train, y_train)  

# Predict using the test features  
y_pred = ridge_model.predict(X_test)  # Use X_test for predictions

y_pred
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.53029e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# array([ 3352.18225173, 13591.42284302,  2251.12985375, ...,
#         1034.0414426 ,   496.7905156 ,   473.5879599 ], shape=(3140,))
